# %%
# ============================================================
# EUROPEAN POWER GRID DATASET - SHARED ACCESS
# ============================================================
# Dataset: electricity_weather_with_forecast
# Time: 2019-2021 (3 years) | Countries: 26 European nations
# Records: 633K hourly observations
# ============================================================

print("LOADING SHARED EUROPEAN POWER GRID DATASET")
print("="*60)

# LOAD THE DATASET
df = spark.table('workspace.default.electricity_weather_with_forecast')

print(f"\n✅ Dataset loaded!")
print(f"   Rows: {df.count():,}")
print(f"   Columns: {len(df.columns)}")
print(f"   Time: 2019-01-01 to 2021-12-07")
print(f"   Countries: 26")

# SHOW SAMPLE
print(f"\n📊 Sample data:")
display(df.limit(10))

# CONVERT TO PANDAS (if needed)
df_pandas = df.toPandas()
print(f"\n✅ Also available as: df_pandas")

# AVAILABLE FEATURES
print(f"\n📋 KEY FEATURES:")
print(f"   • Actual_Load: Real electricity demand (MW)")
print(f"   • Forecasted_Load: Predicted demand (MW)")
print(f"   • Generation types: Nuclear, Solar, Wind, Fossil fuels, etc.")
print(f"   • Weather: temperature, wind_speed, solar_radiation")
print(f"   • net_imports: Cross-border electricity flows")
print(f"   • country: Country code (AT, BE, BG, CH, CZ, DE, DK, EE, ES, FI, FR, GR, HR, HU, IE, IT, LT, LV, NL, NO, PL, PT, RO, SE, SI, SK)")

print("\n" + "="*60)
print("✅ READY! You can now use 'df' or 'df_pandas' for analysis")
print("="*60)
