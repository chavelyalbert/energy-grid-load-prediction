# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = spark.table("workspace.european_grid_raw.load_actual")
display(df)

# Print columns to verify the correct date column name
print(df.columns)

# Replace 'date' with the actual date column name, e.g., 'dt' or 'timestamp'
# For example, if the column is 'dt':
df_pandas = df.toPandas()
df_es_2025 = df_pandas[
    (df_pandas['country'] == 'ES') &
    (pd.to_datetime(df_pandas['index']).dt.year == 2025)
]

spark_df_es_2025 = spark.createDataFrame(df_es_2025)
spark_df_es_2025.write.mode("overwrite").saveAsTable("cleaned_data.test__es_2025_actual_load")
